# %% [markdown]
# ## Getting Team and Stadium Data and Loading it into a PostgreSQL Database

# %% [markdown]
# This notebook will both:
#
# * Create a DataFrame of "Team Data," which really just maps current MLB team names to their abbreviations in different baseball data sources (MLBAM/Statcast and [Baseball-Reference](https://www.baseball-reference.com/)) to create/populate a table `teams` in the `baseball` database created in the previous notebook
# * Scrape dimensions data for each team's home stadium from [Clem's Baseball](http://www.andrewclem.com/Baseball/index.html) to create/populate a table `stadiums` in the `baseball` database.

# %%
import pandas as pd
import re
from bs4 import BeautifulSoup, Comment
import requests

# %% [markdown]
# Let's start off making a couple dictionaries mapping each team name to its MLBAM and Baseball-Reference abbreviation (the latter is not of any use in this project but is there for future use, should Baseball-Reference data be added to the `baseball` database). We'll return to these later in the notebook.

# %%
mlbam_team_dict = {
    'Arizona Diamondbacks': 'ARI',
    'Atlanta Braves': 'ATL',
    'Baltimore Orioles': 'BAL',
    'Boston Red Sox': 'BOS',
    'Chicago Cubs': 'CHC',
    'Chicago White Sox': 'CWS',
    'Cincinnati Reds': 'CIN',
    'Cleveland Indians': 'CLE',
    'Colorado Rockies': 'COL',
    'Detroit Tigers': 'DET',
    'Houston Astros': 'HOU',
    'Kansas City Royals': 'KC',
    'Los Angeles Angels of Anaheim': 'LAA',
    'Los Angeles Dodgers': 'LAD',
    'Miami Marlins': 'MIA',
    'Milwaukee Brewers': 'MIL',
    'Minnesota Twins': 'MIN',
    'New York Mets': 'NYM',
    'New York Yankees': 'NYY',
    'Oakland Athletics': 'OAK',
    'Philadelphia Phillies': 'PHI',
    'Pittsburgh Pirates': 'PIT',
    'San Diego Padres': 'SD',
    'San Francisco Giants': 'SF',
    'Seattle Mariners': 'SEA',
    'St. Louis Cardinals': 'STL',
    'Tampa Bay Rays': 'TB',
    'Texas Rangers': 'TEX',
    'Toronto Blue Jays': 'TOR',
    'Washington Nationals': 'WSH'
}

# %%
bref_team_dict = {
    'Arizona Diamondbacks': 'ARI',
    'Atlanta Braves': 'ATL',
    'Baltimore Orioles': 'BAL',
    'Boston Red Sox': 'BOS',
    'Chicago Cubs': 'CHC',
    'Chicago White Sox': 'CHW',
    'Cincinnati Reds': 'CIN',
    'Cleveland Indians': 'CLE',
    'Colorado Rockies': 'COL',
    'Detroit Tigers': 'DET',
    'Houston Astros': 'HOU',
    'Kansas City Royals': 'KCR',
    'Los Angeles Angels of Anaheim': 'LAA',
    'Los Angeles Dodgers': 'LAD',
    'Miami Marlins': 'MIA',
    'Milwaukee Brewers': 'MIL',
    'Minnesota Twins': 'MIN',
    'New York Mets': 'NYM',
    'New York Yankees': 'NYY',
    'Oakland Athletics': 'OAK',
    'Philadelphia Phillies': 'PHI',
    'Pittsburgh Pirates': 'PIT',
    'San Diego Padres': 'SDP',
    'San Francisco Giants': 'SFG',
    'Seattle Mariners': 'SEA',
    'St. Louis Cardinals': 'STL',
    'Tampa Bay Rays': 'TBR',
    'Texas Rangers': 'TEX',
    'Toronto Blue Jays': 'TOR',
    'Washington Nationals': 'WSN'
}

# %% [markdown]
# Now we'll set ourselves up to scrape the "Current Stadium" links from [Clem's](http://www.andrewclem.com/Baseball/Stadium_lists.html) and then the team name and dimensions data from each stadium page ([example](http://www.andrewclem.com/Baseball/AngelStadium.html)):

# %%
def get_soup(url):
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(re.sub('<!--|-->', '', page), 'html5lib')
    return soup

# %%
# get page and link for each stadium page
soup = get_soup('http://www.andrewclem.com/Baseball/Stadium_lists.html')
curr_stadium_pgs = soup.find('h5', text=re.compile('Current')).find_all_next('a')

# %%
# get just link to each stadium page
curr_stadium_links = [s['href'] for s in curr_stadium_pgs[:30]]

# %%
# scrape team name and dimensions data off each stadium page
stadium_dict = {}
for s in curr_stadium_links:
    sopa = get_soup('http://www.andrewclem.com/Baseball/' + s)
    team_name = re.sub('[\(].*[\)]', '', sopa.find('h1').text.strip().split('of the')[1]).strip()
    team_name = re.sub('\*', '', team_name).strip()
    tbl = sopa.find('table').find_all('tr')
    
    row = [re.sub('[\(\)\*]', '', s.text).strip() for s in tbl[2].find_all('td')[8:13] + tbl[2].find_all('td')[15:20]]
    head = [s.text for s in tbl[1].find_all('th')[7:17]]
    stadium_dict[team_name] = row
stadium_df = pd.DataFrame.from_dict(stadium_dict, orient='index')
stadium_df.columns = head

# %%
stadium_df
# Out:
#                                      Fair      Foul     LF     CF     RF  \
# Los Angeles Angels of Anaheim       106.7      21.5      5      8     18
# St. Louis Cardinals                 112.1      25.2      8      8      8
# Baltimore Orioles                   108.1      23.6      7      7     21
# Arizona Diamondbacks                114.2      25.5      8     25      8
# New York Mets                       109.6      20.7      8      8      8
# Philadelphia Phillies               105.0      24.5     11      6     13
# Detroit Tigers                      113.7      26.5      7      9      9
# Colorado Rockies                    119.2      24.9      8      8     17
# Los Angeles Dodgers            115.8110.5  27.919.3      4      8      4
# Boston Red Sox                      105.5      18.1     37     18      5
# Texas Rangers                       112.6      18.9     14      8      8
# Cincinnati Reds                     106.1      23.6     12      8      8
# Chicago White Sox                   105.3      25.0      8      8      8
# Kansas City Royals                  118.5      22.9      9      9      9
# Miami Marlins                       114.5      19.1     12      9     12
# Milwaukee Brewers                   111.2      21.1      8      8      8
# Houston Astros                      107.0      21.0     21      9      7
# Washington Nationals                109.1      22.8  10, 9  10, 9  16, 9
# Oakland Athletics                   108.7      40.7      8      8      8
# San Francisco Giants                110.8      25.5      8      8     25
# San Diego Padres                    110.9      23.9      4      7     10
# Pittsburgh Pirates                  111.2      22.2      6     10     21
# Cleveland Indians                   105.4      21.9     19      9      9
# Toronto Blue Jays                   109.5      30.5      8      8      8
# Atlanta Braves                      109.3      22.3      6      8     16
# Minnesota Twins                     108.9      20.7      8      8     23
# Tampa Bay Rays                      108.9      25.3     11      9     11
# Seattle Mariners                    106.1      24.3     15      7      7
# Chicago Cubs                        107.8      16.5     16     11     16
# New York Yankees                    108.8      19.7      8      8      8
#
#                               Left field Left-center Center field  \
# Los Angeles Angels of Anaheim        333         390          400
# St. Louis Cardinals                  336         375          400
# Baltimore Orioles                    333         364          400
# Arizona Diamondbacks                 330         376          407
# New York Mets                        335         362          408
# Philadelphia Phillies                329         360          401
# Detroit Tigers                       345         370          420
# Colorado Rockies                     347         390          415
# Los Angeles Dodgers                  330         375          395
# Boston Red Sox                       310         335          390
# Texas Rangers                        332         380          400
# Cincinnati Reds                      328         368          404
# Chicago White Sox                    335         365          400
# Kansas City Royals                   330         385          410
# Miami Marlins                        344         386          407
# Milwaukee Brewers                    344         370          400
# Houston Astros                       315         335          409
# Washington Nationals                 336         377          402
# Oakland Athletics                    330         362          400
# San Francisco Giants                 339         365          399
# San Diego Padres                     334         380          396
# Pittsburgh Pirates                   325         388          399
# Cleveland Indians                    325         360          405
# Toronto Blue Jays                    328         375          400
# Atlanta Braves                       335         385          400
# Minnesota Twins                      339         377          404
# Tampa Bay Rays                       315         370          404
# Seattle Mariners                     331         367          401
# Chicago Cubs                         355         352          395
# New York Yankees                     318         382          408
#
#                               Right-center Right field
# Los Angeles Angels of Anaheim          370         333
# St. Louis Cardinals                    375         335
# Baltimore Orioles                      373         318
# Arizona Diamondbacks                   376         335
# New York Mets                          375         330
# Philadelphia Phillies                  355         330
# Detroit Tigers                         388         330
# Colorado Rockies                       375         350
# Los Angeles Dodgers                    375         330
# Boston Red Sox                         378         302
# Texas Rangers                          381         325
# Cincinnati Reds                        370         325
# Chicago White Sox                      365         330
# Kansas City Royals                     385         330
# Miami Marlins                          392         335
# Milwaukee Brewers                      374         345
# Houston Astros                         373         326
# Washington Nationals                   370         335
# Oakland Athletics                      362         330
# San Francisco Giants                   385         309
# San Diego Padres                       372         322
# Pittsburgh Pirates                     365         320
# Cleveland Indians                      375         325
# Toronto Blue Jays                      375         328
# Atlanta Braves                         375         325
# Minnesota Twins                        367         328
# Tampa Bay Rays                         370         322
# Seattle Mariners                       367         326
# Chicago Cubs                           368         353
# New York Yankees                       360         314

# %%
# df.index = df.index.map(team_dict)

# %% [markdown]
# We see there are some oddities for the Los Angeles Dodgers ([Dodger Stadium](http://www.andrewclem.com/Baseball/DodgerStadium.html)) and Washington Nationals ([Nationals Park](http://www.andrewclem.com/Baseball/NationalsPark.html)). For now, we will take the lower value for `LF`, `CF` and `RF` for Washington (these are the heights of their corresponding OF walls) and the second numerical value for `Fair` and `Foul` area dimensions for the Dodgers (as specified on the Dodger Stadium page).

# %%
stadium_df.loc['Washington Nationals']['LF'] = stadium_df.loc['Washington Nationals']['LF'].split(', ')[1]
stadium_df.loc['Washington Nationals']['CF'] = stadium_df.loc['Washington Nationals']['CF'].split(', ')[1]
stadium_df.loc['Washington Nationals']['RF'] = stadium_df.loc['Washington Nationals']['RF'].split(', ')[1]

# %%
stadium_df.loc['Los Angeles Dodgers']['Fair'] = 110.5
stadium_df.loc['Los Angeles Dodgers']['Foul'] = 19.3

# %% [markdown]
# Let's now further clean up the stadium dimension data: convert everything to numeric, make the team names a column and not the index, and rename the columns:

# %%
stadium_df = stadium_df.apply(pd.to_numeric)

# %%
stadium_df = stadium_df.reset_index().rename(columns={'index': 'Team'})

# %%
stadium_df
# Out:
#                              Team   Fair  Foul  LF  CF  RF  Left field  \
# 0   Los Angeles Angels of Anaheim  106.7  21.5   5   8  18         333
# 1             St. Louis Cardinals  112.1  25.2   8   8   8         336
# 2               Baltimore Orioles  108.1  23.6   7   7  21         333
# 3            Arizona Diamondbacks  114.2  25.5   8  25   8         330
# 4                   New York Mets  109.6  20.7   8   8   8         335
# 5           Philadelphia Phillies  105.0  24.5  11   6  13         329
# 6                  Detroit Tigers  113.7  26.5   7   9   9         345
# 7                Colorado Rockies  119.2  24.9   8   8  17         347
# 8             Los Angeles Dodgers  110.5  19.3   4   8   4         330
# 9                  Boston Red Sox  105.5  18.1  37  18   5         310
# 10                  Texas Rangers  112.6  18.9  14   8   8         332
# 11                Cincinnati Reds  106.1  23.6  12   8   8         328
# 12              Chicago White Sox  105.3  25.0   8   8   8         335
# 13             Kansas City Royals  118.5  22.9   9   9   9         330
# 14                  Miami Marlins  114.5  19.1  12   9  12         344
# 15              Milwaukee Brewers  111.2  21.1   8   8   8         344
# 16                 Houston Astros  107.0  21.0  21   9   7         315
# 17           Washington Nationals  109.1  22.8   9   9   9         336
# 18              Oakland Athletics  108.7  40.7   8   8   8         330
# 19           San Francisco Giants  110.8  25.5   8   8  25         339
# 20               San Diego Padres  110.9  23.9   4   7  10         334
# 21             Pittsburgh Pirates  111.2  22.2   6  10  21         325
# 22              Cleveland Indians  105.4  21.9  19   9   9         325
# 23              Toronto Blue Jays  109.5  30.5   8   8   8         328
# 24                 Atlanta Braves  109.3  22.3   6   8  16         335
# 25                Minnesota Twins  108.9  20.7   8   8  23         339
# 26                 Tampa Bay Rays  108.9  25.3  11   9  11         315
# 27               Seattle Mariners  106.1  24.3  15   7   7         331
# 28                   Chicago Cubs  107.8  16.5  16  11  16         355
# 29               New York Yankees  108.8  19.7   8   8   8         318
#
#     Left-center  Center field  Right-center  Right field
# 0           390           400           370          333
# 1           375           400           375          335
# 2           364           400           373          318
# 3           376           407           376          335
# 4           362           408           375          330
# 5           360           401           355          330
# 6           370           420           388          330
# 7           390           415           375          350
# 8           375           395           375          330
# 9           335           390           378          302
# 10          380           400           381          325
# 11          368           404           370          325
# 12          365           400           365          330
# 13          385           410           385          330
# 14          386           407           392          335
# 15          370           400           374          345
# 16          335           409           373          326
# 17          377           402           370          335
# 18          362           400           362          330
# 19          365           399           385          309
# 20          380           396           372          322
# 21          388           399           365          320
# 22          360           405           375          325
# 23          375           400           375          328
# 24          385           400           375          325
# 25          377           404           367          328
# 26          370           404           370          322
# 27          367           401           367          326
# 28          352           395           368          353
# 29          382           408           360          314

# %%
stadium_df.columns = ['team', 'fair', 'foul', 'lf_ht', 'cf_ht', 'rf_ht', 'lf', 'lc', 'cf', 'rc', 'rf']

# %% [markdown]
# OK, now we are ready to load this DataFrame into the `baseball` database. Let's make the `CREATE TABLE` statement for the `stadiums` table, connect to the `baseball` database and execute `CREATE TABLE` statement:

# %%
from psycopg2 import connect

# %%
create_stadium_tbl = '''
    CREATE TABLE IF NOT EXISTS stadiums(
        team TEXT,
        fair FLOAT,
        foul FLOAT,
        lf_ht INT,
        cf_ht INT,
        rf_ht INT,
        lf INT,
        lc INT,
        cf INT,
        rc INT,
        rf INT
    );
'''

# %%
conn = connect("dbname=baseball user= password=")
cur = conn.cursor()

# %%
cur.execute(create_stadium_tbl)
conn.commit()

# %% [markdown]
# Now we'll insert each row from this DataFrame into the `stadiums` table, similarly to what we did for the `statcast` table in the previous notebook:

# %%
cols = ", ".join([str(i) for i in stadium_df.columns.tolist()])
cols
# Out:
# 'team, fair, foul, lf_ht, cf_ht, rf_ht, lf, lc, cf, rc, rf'

# %%
for i, row in stadium_df.iterrows():
    query = "INSERT INTO stadiums (" +cols + ") VALUES (" + "%s,"*(len(row)-1) + "%s)"
    cur.execute(query, tuple(row))
    conn.commit()

# %% [markdown]
# Finally, we'll create the `team` table to be added to the `baseball` database. We make the `CREATE TABLE` statement for this table, merge the two team dictionaries created at the beginning of the notebook, execute the `CREATE TABLE` statement and finally insert the rows of our team DataFrame into the `team` table in the `baseball` database.

# %%
create_team_tbl = '''
    CREATE TABLE IF NOT EXISTS teams(
        team TEXT,
        mlb_id TEXT,
        bref_id TEXT
    );
'''

# %%
teams_df = pd.DataFrame.from_dict(mlbam_team_dict, orient='index').\
    merge(pd.DataFrame.from_dict(bref_team_dict, orient='index'), left_index=True, right_index=True)
teams_df.columns = ['mlb_id', 'bref_id']
teams_df = teams_df.reset_index().rename(columns={'index': 'team'})
teams_df
# Out:
#                              team mlb_id bref_id
# 0            Arizona Diamondbacks    ARI     ARI
# 1                  Atlanta Braves    ATL     ATL
# 2               Baltimore Orioles    BAL     BAL
# 3                  Boston Red Sox    BOS     BOS
# 4                    Chicago Cubs    CHC     CHC
# 5               Chicago White Sox    CWS     CHW
# 6                 Cincinnati Reds    CIN     CIN
# 7               Cleveland Indians    CLE     CLE
# 8                Colorado Rockies    COL     COL
# 9                  Detroit Tigers    DET     DET
# 10                 Houston Astros    HOU     HOU
# 11             Kansas City Royals     KC     KCR
# 12  Los Angeles Angels of Anaheim    LAA     LAA
# 13            Los Angeles Dodgers    LAD     LAD
# 14                  Miami Marlins    MIA     MIA
# 15              Milwaukee Brewers    MIL     MIL
# 16                Minnesota Twins    MIN     MIN
# 17                  New York Mets    NYM     NYM
# 18               New York Yankees    NYY     NYY
# 19              Oakland Athletics    OAK     OAK
# 20          Philadelphia Phillies    PHI     PHI
# 21             Pittsburgh Pirates    PIT     PIT
# 22               San Diego Padres     SD     SDP
# 23           San Francisco Giants     SF     SFG
# 24               Seattle Mariners    SEA     SEA
# 25            St. Louis Cardinals    STL     STL
# 26                 Tampa Bay Rays     TB     TBR
# 27                  Texas Rangers    TEX     TEX
# 28              Toronto Blue Jays    TOR     TOR
# 29           Washington Nationals    WSH     WSN

# %%
cur.execute(create_team_tbl)
conn.commit()

# %%
cols = ", ".join([str(i) for i in teams_df.columns.tolist()])
cols
# Out:
# 'team, mlb_id, bref_id'

# %%
for i, row in teams_df.iterrows():
    query = "INSERT INTO teams (" +cols + ") VALUES (" + "%s,"*(len(row)-1) + "%s)"
    cur.execute(query, tuple(row))
    conn.commit()

# %%
cur.close()
conn.close()
